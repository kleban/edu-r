# %% [markdown]
# # Варіанти завдань до Лабораторної роботи №1 "Основи програмування в R"

# %% [markdown]
# з курсу "Вступ до програмування для Data Science", для студентів 1 курсу спеціальності 072 Фінанси та бізнес-аналітика

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-info">Під час виконання завдання студент/ка зобовязується дотримуватися <a href="https://www.oa.edu.ua/publik_information/CODEX.pdf">Кодексу академічної доброчесності Національного університету. «Острозька академія»</a></div>

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Основи алгоритмізації

# %% [markdown]
# ### 3.1. Вектори

# %% [markdown]
# ### 3.2. Дата-фрейми

# %% [markdown]
# #### 3.2.1. Обчислення

# %% [markdown]
# > Примітка. **`V`** у формулі означає номер Вашого варіанту.

# %% [markdown]
# <div class="alert alert-info">
#     Якщо для Вашого варіанту завдання значення `Y` мають дуже близькі або дуже великі значення і відсутня можливість порахувати, наприклад, суми парних/непарних - зверніться до викладача, можливо варто змінити формулу для обчислень.
# </div>

# %% [markdown]
# | № варіанту | Функція | Діапазон значень `X` | Інші умови |
# | --- | --- | --- | --- |
# |1|$y = 21*e^{x+1} + \frac{x^4+x-7}{x^2-sin(V)} + V$ | [1.5;2,5] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |2|$y = \frac{cos(x^2)+V^2}{sin(x^3+5)-ln(x+V^2)}$ | [100.1;115] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |3|$y = \frac{cos(x^2)+V^2}{cos(x+4)-ln(x+V^2)}$ | [1000;3000] з короком 25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |4|$y = sin(x^2) + \frac{x^2+cos(x+V)}{x^3-sqrt(x)}$ | [350;450] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |5|$y = V*e^{x-1} + \frac{x^3+V-9}{x-ln(x^2)}$ | [15.01;20] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |6|$y = \frac{cos(x^2)+V}{cos(x^2)-ln(x+V^2)}$ | [1;50] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |7|$y = sin(x) + \frac{x^2+ln(x^2+V)}{x-sqrt(x^3)}$ | [450;550] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |8|$y = V*e^{x+1} + \frac{x^3+x-6}{x^2-sin(V)} + V$ | [4.5;5,5] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |9|$y = \frac{cos(x^3)+V^2}{cos(x^2+4)-ln(x+V^2)}$ | [120;135] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |10|$y = cos(x) + \frac{x^5+ln(x+V+1)}{x^2-sqrt(x)}$ | [100;200] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |11|$y = V + 100*e^x + \frac{x^2+x-1}{x-ln(x)}$ | [0.01;1] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |12|$y = \frac{x^4+V}{cos(x)-ln(x+V)}$ | [0.1;5] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |13|$y = cos(x) + \frac{x^2+ln(x^2+V)}{x-sqrt(x^3)}$ | [150;250] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |14|$y = 30*e^{x+1} + \frac{x^3+x-4}{x^2-sin(x)} + V$ | [0.5;1,5] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |15|$y = \frac{cos(x^2)+V^2}{cos(x+4)-ln(x+V^2)}$ | [10.1;15] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |16|$y = sin(x^2) + \frac{x^2+cos(x+V)}{x^3-sqrt(x)}$ | [200;300] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |17|$y = V*e^{x-1} + \frac{x^3+V-5}{x-ln(x)}$ | [1.01;2] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |18|$y = \frac{x^2+V}{cos(x^2)-ln(x+V)}$ | [0.1;5] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |19|$y = cos(x) + \frac{x^2+ln(x^2+V)}{x-sqrt(x^3)}$ | [250;350] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |20|$y = 30*e^{x+1} + \frac{x^3+x-4}{x^2-sin(x)} + V$ | [0.5;1,5] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |21|$y = \frac{cos(x^2)+V^2}{cos(x+4)-ln(x+V^2)}$ | [10.1;15] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |22|$y = sin(x^2) + \frac{x^2+cos(x+V)}{x^3-sqrt(x)}$ | [200;300] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |23|$y = V*e^{x-1} + \frac{x^3+V-5}{x-ln(x)}$ | [1.01;2] з короком 0.005 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |24|$y = \frac{x^2+V}{cos(x^2)-ln(x+V)}$ | [0.1;5] з короком 0.25 | Заокруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |
# |25|$y = cos(x) + \frac{x^2+ln(x^2+V)}{x-sqrt(x^3)}$ | [250;350] з короком 0.5 | Заокруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |

# %% [markdown]
# ### 3.3. Функції

# %% [markdown]
# | № варіанту | Функція | Додаткова інформація |
# | --- | --- | --- |
# | 1 | Обчислення площі трикутника | Функція повинна приймати сторони трикутника як окремі параметри та повертати його площу. Також потрібно перевірити можливість існування такого трикутника та невід'ємність чисел. Якщо якісь параметри не відповідають вимогам, то потрібно вивести інформацію про це. Функція повинна повертати значення площі |
# | 2 | Обчислення об'єму прямокутної кімнати | Функція повинна приймати сторони кімнати об'єм. Потрібно перевірити невід'ємність чисел. Якщо якісь параметри не відповідають вимогам, то потрібно вивести інформацію про це. Функція повинна повертати об'єм кімнати. |
# | 3 | Конвертація валюти | Функція повинна приймати базову валюту, в яку будемо конвертувати, курс та суму. Потрібно перевірити невід'ємність чисел. Якщо якісь параметри не відповідають вимогам, то потрібно вивести інформацію про це. Функція повинна повертати текст у стилі "Якщо конвертувати 1000 UAH у USD за курсом 39.2, то отримаємо 24.52 USD" |
# | 4 | Перевірка на простоту числа| Напишіть функцію, яка приймає ціле число як параметр і повертає логічне значення, що показує, чи є це число простим. Потрібно перевірити, чи є вхідне число більше 1, і чи ділиться воно лише на 1 і на себе |
# | 5 | Калькулятор факторіалу|Напишіть функцію, яка приймає невід'ємне ціле число як вхідний параметр і повертає його факторіал. Перевірте вхідне значення на невід'ємність|
# | 6 | Генерація послідовності Фібон | ння: Напишіть функцію, яка приймає ціле ч'и'сло n як вхідний параметр і повертає список перших n чисел послідовності Фібоначчі. Перевірте, щоб n було невід'ємним|
# | 7 | Перевірка на пал|дання: Напишіть функцію, яка приймає рядок як вхідний параметр і повертає логічне значення, що показує, чи є цей рядок паліндромом (тобто, чи читається він однаково з обох боків). Перевірте, щоб рядок був не порожнім|
# | 8 | Конвертер температури| Напишіть функцію, яка конвертує температуру з одиниць Цельсія в одиниці Фаренгейта (або навпаки). Перевірте, щоб вхідне значення було числом.|
# | 9 | Пошук найбільшого спільного дільника (НСД)|Напишіть функцію, яка приймає два цілих числа як вхідні параметри і повертає їх найбільший спільний дільник (НСД). Перевірте, щоб обидва числа були невід'ємними|
# | 10 | Генератор випадкового пароля|Напишіть функцію, яка генерує випадковий пароль заданої довжини. Пароль повинен містити комбінацію великих і малих літер, цифр і спеціальних символів. Кількість символів повинна бути параметром функції|
# | 11 | Перевірка на простоту числа |  Напишіть функцію, яка приймає список цілих чисел як вхідний параметр і повертає список логічних значень, що показують, чи є кожне число простим. Перевірте, щоб всі числа в списку були невід'ємими|
# | 12 | Розширений калькулятор|Напишіть функцію, яка приймає два числа і операцію (+, -, *, /) як вхідні параметри і повертає результат цієї операції. Перевірте, щоб операція була валідною, і уникайте ділення на 0|
# | 13 | Перевірка н анаграму| Напишіть функцію, яка приймає два рядки як вхідні параметри і повертає логічне значення, що показує, чи є ці рядки анаграмами (тобто, чи складаються вони з одних і тих же символів у різному порядку). Перевірте, щоб обидва рядки були неустими|
# | 14 | Обчислення кількості слів у рядку | Напишіть функцію, яка приймає рядок тексту як вхідний параметр і повертає кількість слів у цьому рядку. Слова можуть бути розділені пробілами, комами та іншими знаками пунктуації|
# | 15 |  Пошук максимального елемента в матриц | Напишіть функцію, яка приймає матрицю як вхідний параметр і повертає максимальний елемент у цій матриці.|
# | 16 | Сортування списку за довжиною елементів |  Напишіть функцію, яка приймає список рядків як вхідний параметр і повертає цей список, відсортований за довжиною елементів у зростаючому порядку.|
# | 17 | Пошук простих чисел у заданому діапазоні | Напишіть функцію, яка приймає два цілі числа - початок і кінець діапазону - і повертає список простих чисел у цьому діапазоні |
# | 18 | Перевірка на арифметичну прогресію | Напишіть функцію, яка приймає список цілих чисел як вхідний параметр і повертає логічне значення, що показує, чи утворюють ці числа арифметичну прогресію.|
# | 19 | Перевірка на простоту числа |  Напишіть функцію, яка приймає список цілих чисел як вхідний параметр і повертає список логічних значень, що показують, чи є кожне число простим. Перевірте, щоб всі числа в списку були невід'ємими|
# | 20 | Розширений калькулятор|Напишіть функцію, яка приймає два числа і операцію (+, -, *, /) як вхідні параметри і повертає результат цієї операції. Перевірте, щоб операція була валідною, і уникайте ділення на 0|
# | 21 | Перевірка н анаграму| Напишіть функцію, яка приймає два рядки як вхідні параметри і повертає логічне значення, що показує, чи є ці рядки анаграмами (тобто, чи складаються вони з одних і тих же символів у різному порядку). Перевірте, щоб обидва рядки були неустими|
# | 22 | Обчислення кількості слів у рядку | Напишіть функцію, яка приймає рядок тексту як вхідний параметр і повертає кількість слів у цьому рядку. Слова можуть бути розділені пробілами, комами та іншими знаками пунктуації|
# | 23 |  Пошук максимального елемента в матриц | Напишіть функцію, яка приймає матрицю як вхідний параметр і повертає максимальний елемент у цій матриці.|
# | 24 | Сортування списку за довжиною елементів |  Напишіть функцію, яка приймає список рядків як вхідний параметр і повертає цей список, відсортований за довжиною елементів у зростаючому порядку.|
# | 25 | Пошук простих чисел у заданому діапазоні | Напишіть функцію, яка приймає два цілі числа - початок і кінець діапазону - і повертає список простих чисел у цьому діапазоні |
# | 26 | Перевірка на арифметичну прогресію | Напишіть функцію, яка приймає список цілих чисел як вхідний параметр і повертає логічне значення, що показує, чи утворюють ці числа арифметичну прогресію.|

# %% [markdown]
# ## 4. Статистика

# %% [markdown]
# | № варіанту | Посилання на набір даних |
# | --- | ----------- |
# |1|[Superstore Marketing Campaign ](https://www.kaggle.com/datasets/ahsan81/superstore-marketing-campaign-dataset)|
# |2|[Walmart Sales](https://www.kaggle.com/datasets/mikhail1681/walmart-sales)|
# |3|[Student Behaviour](https://www.kaggle.com/datasets/nitishjolly/student-behaviour)|
# |4|[Marketing Campaign](https://www.kaggle.com/datasets/rodsaldanha/arketing-campaign)|
# |5|[Rural Credit Dataset](https://www.kaggle.com/datasets/ikjotsingh221/rural-credit-dataset-cleaned)|
# |6|[Taxi Trip](https://www.kaggle.com/datasets/anandshaw2001/taxi-dataset)|
# |7|[Customer Churn](https://www.kaggle.com/datasets/anandshaw2001/customer-churn-dataset)|
# |8|[Shopping Mall Custome](https://www.kaggle.com/datasets/zubairmustafa/shopping-mall-customer-segmentation-data)|
# |9|[Abalone](https://www.kaggle.com/datasets/alicenkbaytop/abalone-dataset)|
# |10|[Loan](https://www.kaggle.com/datasets/saramah/loan-data)|
# |11|[Career](https://www.kaggle.com/datasets/utkarshshrivastav07/career-prediction-dataset)|
# |12|[Essay](https://www.kaggle.com/datasets/fatihfurkankurt/essay-examination-data-set)|
# |13|[WildFires](https://www.kaggle.com/datasets/imtkaggleteam/wildfires)|
# |14|[Marketing](https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data)|
# |15|[Top Grossing Movies](https://www.kaggle.com/datasets/akankshaaa013/top-grossing-movies-dataset)|
# |16|[Video Games](https://www.kaggle.com/datasets/gregorut/videogamesales)|
# |17|[Customer Retention](https://www.kaggle.com/datasets/anandshaw2001/customer-churn-dataset)|
# |18|[Shopping Mall 2019](https://www.kaggle.com/datasets/zubairmustafa/shopping-mall-customer-segmentation-data)|
# |19|[Dataset3](https://www.kaggle.com/datasets/alicenkbaytop/abalone-dataset)|
# |20|[Loan Prediction](https://www.kaggle.com/datasets/saramah/loan-data)|
# |21|[Career Advs Prediction](https://www.kaggle.com/datasets/utkarshshrivastav07/career-prediction-dataset)|
# |22|[Essay information school](https://www.kaggle.com/datasets/fatihfurkankurt/essay-examination-data-set)|
# |23|[Wild Fires Stats](https://www.kaggle.com/datasets/imtkaggleteam/wildfires)|
# |24|[Marketing Dataset 2020](https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data)|
# |25|[Movies](https://www.kaggle.com/datasets/akankshaaa013/top-grossing-movies-dataset)|
# |26|[Games](https://www.kaggle.com/datasets/gregorut/videogamesales)|

# %% [markdown]
# ## 5. Робота з даними

# %% [markdown]
# ### 5.1-5.2. Генерація даних та обчислення

# %% [markdown]
# > Генеруйте дані таким чином, щоб вони були реалістичними для сценарію Вашої теми. Наприклад, якщо це продажі автомобілів, то мають бути присутні справжні марки, реалістичні роки випуску, ціни та пробіги.

# %% [markdown]
# ![image.png](attachment:fe3fd773-8a95-4428-ac9b-7ea2be8ab386.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:e09458b0-b597-4589-8ad6-15cb465c3278.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:835898cc-f506-47d7-bf39-8d15022cf845.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:b5b688d6-e29d-4369-ad48-1432d717cf1f.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:f3d8ea38-ccd4-4df9-b205-188a65394572.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:16de79a6-d117-40f1-845a-a1899a1d9e93.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:126c9230-db3e-4acd-838e-974c007759f6.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:96e99633-e976-43c7-8f67-2f89da90eef6.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:0cd44cb0-53f3-4be5-ba86-bd374af3b6bb.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:119fb7b7-c243-4bbb-9dbe-1a30987d143e.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:f329bce2-4038-4940-9dc9-9ab934495347.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:b2ddd1ed-a0c5-4fde-ac91-9e14ecbbccd7.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:770c863d-fa41-4e13-96d8-6d8b1878154e.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:baf13d70-55d3-4261-b94e-4a9a8e7c8058.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:b1431bd3-aa42-475c-acf8-27769421c963.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:c7aa259c-481d-4f2a-b987-328a29d96b53.png)

# %% [markdown]
# ![image.png](attachment:a3900109-c483-4288-9cb9-1bb33f387032.png)

# %% [markdown]
# ![image.png](attachment:03d0bfb6-9de2-46d8-923e-373e82f22a5d.png)

# %% [markdown]
# ![image.png](attachment:9f0a1cfa-7b63-46a9-876d-1d75ea54e144.png)

# %% [markdown]
# ![image.png](attachment:9fbfc38f-c6aa-44d0-82d8-4b51b7a9b991.png)

# %% [markdown]
# ![image.png](attachment:590de8ed-1f43-44fc-a1df-73cf45ebcb96.png)

# %% [markdown]
# ![image.png](attachment:e2a0b24e-be93-4f29-a8e5-225201ddb798.png)

# %% [markdown]
# ![image.png](attachment:d81791b4-8627-4e90-a158-4d8a448b66eb.png)

# %% [markdown]
# ![image.png](attachment:d6010941-b798-481c-9783-fb9235b188cb.png)

# %% [markdown]
# ![image.png](attachment:fd884c66-f993-4442-a819-2adfcff8de8d.png)

# %% [markdown]
# ![image.png](attachment:5be408d2-d8ec-4d9f-94b3-15da8140ac87.png)

# %% [markdown]
# ![image.png](attachment:04e82ecd-6cdb-41a8-b86d-8958375e08fd.png)

# %% [markdown]
# ![image.png](attachment:c996e006-b3c0-4287-a3ed-29e8497d2b69.png)

# %% [markdown]
# ![image.png](attachment:31705166-9f8c-49ba-aa25-a5396d1b91c8.png)

# %% [markdown]
# ![image.png](attachment:0dfb7f1e-536c-43b7-a071-e8f966845ac7.png)

# %% [markdown]
# ![image.png](attachment:133f7a51-0970-4e15-a0b1-2d0916cdd516.png)

# %% [markdown]
# ![image.png](attachment:650479a4-16ff-4889-a481-ee2909475b31.png)

# %% [markdown]
# ---

# %% [markdown]
# &copy; Юрій Клебан. Частина завдань згенеровано chatGPT.
