# %% [markdown]
# # Лабораторна робота №1. Читання та маніпулювання даними з використанням dplyr

# %% [markdown]
# ---

# %% [markdown]
# Виконав: Юрій Клебан, ЕК-4

# %% [markdown]
# ## Завдання 1

# %%
library(dplyr)
library(lubridate)

# %%
data <- read.csv("data/bikes.csv")
data |> head()
# Out:
#              datetime season holiday workingday weather temp  atemp humidity
# 1 2011-01-01 00:00:00      1       0          0       1 9.84 14.395       81
# 2 2011-01-01 01:00:00      1       0          0       1 9.02 13.635       80
# 3 2011-01-01 02:00:00      1       0          0       1 9.02 13.635       80
# 4 2011-01-01 03:00:00      1       0          0       1 9.84 14.395       75
# 5 2011-01-01 04:00:00      1       0          0       1 9.84 14.395       75
# 6 2011-01-01 05:00:00      1       0          0       2 9.84 12.880       75
#   windspeed casual registered count
# 1    0.0000      3         13    16
# 2    0.0000      8         32    40
# 3    0.0000      5         27    32
# 4    0.0000      3         10    13
# 5    0.0000      0          1     1
# 6    6.0032      0          1     1

# %%
#data$datetime <- ymd_hms(data$datetime)

# %% [markdown]
# ### Опис поля `datetime`

# %%
cat("datetime: ", class(data$datetime), "\n")
cat("min: ", min(data$datetime), "\n")
cat("max: ", max(data$datetime), "\n")
# Out:
# datetime:  character
# min:  2011-01-01 00:00:00
# max:  2012-12-19 23:00:00

# %% [markdown]
# ### Опис поля `holiday`

# %%
table(data$holiday)
# Out:
#     0     1
# 10575   311
