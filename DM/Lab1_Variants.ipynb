# %% [markdown]
# # Варіанти завдань до Лабораторної роботи №1 "Основи програмування та аналізу даних в R"

# %% [markdown]
# з курсу "DATA-аналіз у маркетингу", для студентів 2 курсу спеціальності 072 DATA-маркетинг

# %% [markdown]
# ---

# %% [markdown]
# ## !!!

# %% [markdown]
# Під час виконання завдання студент/ка зобовязується дотримуватися [Кодексу академічної доброчесності Національного університету. «Острозька академія»](https://www.oa.edu.ua/publik_information/CODEX.pdf)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Основи алгоритмізації

# %%
#2.1.

# %% [markdown]
# ### 2.1. Вектори

# %% [markdown]
# ### 2.2. Дата-фрейми

# %% [markdown]
# #### 2.2.1. Обчислення

# %% [markdown]
# > Примітка. **`V`** у формулі означає номер Вашого варіанту. |

# %% [markdown]
# | № варіанту | Функція | Діапазон значень `X` | Інші умови |
# | --- | --- | --- | --- |
# |1|$y = cos(x) + \frac{x^3+ln(x+V)}{x^2-sqrt(x)}$ | [100;200] з короком 0.5 | Заоркруглити усі значення `Y` до наближчого меншого цілого числа. Знайти суму `Y` кратних 7.  |
# |2|$y = V + 100*e^x + \frac{x^2+x-1}{x-ln(x)}$ | [0.01;1] з короком 0.005 | Заоркруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` кратних 3.  |
# |3|$y = \frac{x^4+V}{cos(x)-ln(x+V)}$ | [0.1;5] з короком 0.25 | Заоркруглити усі значення `Y` до наближчого більшого цілого числа. Знайти суму непарних `Y` для `X` парних.  |

# %% [markdown]
# | 1 |

# %% [markdown]
# ### 2.3. Функції

# %% [markdown]
# | № варіанту | Функція | Додаткова інформація |
# | --- | --- | --- |
# | 1 | Обчислення площі трикутника | Функція повинна приймати сторони трикутника як окремі параметри та повертати його площу. Також потрібно перевірити можливість існування такого трикутника та невід'ємність чисел. Якщо якісь параметри не відповідають вимогам, то потрібно вивести інформацію про це. |
# | 6 | Обчислення об'єму прямокутної кімнати | Функція повинна приймати сторони кімнати об'єм. Потрібно перевірити невід'ємність чисел. Якщо якісь параметри не відповідають вимогам, то потрібно вивести інформацію про це. |

# %% [markdown]
# ## 4. Робота з даними

# %% [markdown]
# > Генеруйте дані таким чином, щоб вони були реалістичними для сценарію Вашої теми. Наприклад, якщо це продажі автомобілів, то мають бути присутні справжні марки, реалістичні роки випуску, ціни та пробіги.

# %% [markdown]
# ### Варіант 1

# %% [markdown]
# ![image.png](attachment:81e79b2c-1cdd-442b-a152-a061f40bf94a.png)родажу.

# %% [markdown]
# ### Варіант 2

# %% [markdown]
# ![image.png](attachment:9b0a62c0-e6c4-48df-8cf1-ef8697c1245e.png)

# %% [markdown]
# ### Варіант 3

# %% [markdown]
# ![image.png](attachment:608b3f54-1f18-4328-942a-4f81773a60de.png)

# %% [markdown]
# ### Варіант 4

# %% [markdown]
# ![image.png](attachment:3a1f6c87-bbca-4ac3-9ca5-3e3ca2f72d8f.png)

# %% [markdown]
# ### Варіант 5

# %% [markdown]
# ![image.png](attachment:85a21ddb-956e-41a1-9530-34630d8eeef1.png)

# %% [markdown]
# ### Варіант 6
